# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
from sklearn import datasets

# %%
iris=datasets.load_iris()
iris_data=iris.data
iris_labels=iris.target
print(iris_data)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
x_train, x_test, y_train, y_test=(train_test_split(iris_data, iris_labels, test_size=0.20))

# %%
classifier=KNeighborsClassifier(n_neighbors=6)
classifier.fit(x_train, y_train)
y_pred=classifier.predict(x_test)

# %%
print("accuracy is")
print(classification_report(y_test, y_pred))
# Out:
# accuracy is
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.71      1.00      0.83        10
#            2       1.00      0.71      0.83        14
#
#     accuracy                           0.87        30
#    macro avg       0.90      0.90      0.89        30
# weighted avg       0.90      0.87      0.87        30

# %%
cm=confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 6,  0,  0],
#        [ 0, 10,  0],
#        [ 0,  4, 10]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,10))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
dataset=pd.read_csv('Iris.csv')

# %%
dataset.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
plt.figure(figsize=(7,4),dpi=100)

plt.scatter(dataset.SepalLengthCm,dataset.Species)

plt.title('Iris_Chart',size=35,c='black')

plt.xlabel('SepalLengthCm',size=30,c='green')

plt.ylabel('Species',size=30,c='blue')

plt.grid()

plt.show()

# %%
plt.figure(figsize=(7,4),dpi=100)

plt.scatter(dataset.SepalWidthCm,dataset.Species)

plt.title('Iris_Chart',size=35,c='black')

plt.xlabel('SepalWidthCm',size=30,c='green')

plt.ylabel('Species',size=30,c='blue')

plt.grid()

plt.show()

# %%
plt.figure(figsize=(7,4),dpi=100)

plt.scatter(dataset.PetalLengthCm,dataset.Species)

plt.title('Iris_Chart',size=35,c='black')

plt.xlabel('PetalLengthCm',size=30,c='green')

plt.ylabel('Species',size=30,c='blue')

plt.grid()

# %%
plt.figure(figsize=(7,4),dpi=100)

plt.scatter(dataset.PetalWidthCm,dataset.Species)

plt.title('Iris_Chart',size=35,c='black')

plt.xlabel('PetalWidthCm',size=30,c='green')

plt.ylabel('Species',size=30,c='blue')

plt.grid()

plt.show()
